# %% [markdown]
# <a href="https://colab.research.google.com/github/iqalexmdz100/HolaMundo/blob/main/Ejercicio3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programación en Python
#
# Esta notebook especifica a la sesión de "Programación en python" (parte 3) del curso en Inteligencia Artificial [Instituto Tecnológico de Los Mochis](https://www.mochis.tecnm.mx/)
#
# ## Instrucciones
#
# Seguir indicaciones de guía.
#
# ## Licencia de la notebook
#
# ## General information
#
# > **Last updated**: 08/08/2023

# %% [markdown]
# # 1 Importar Pandas

# %%
# A lo mejor hay que instalarlo, descomentar la siguiente línea
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # 2 Abriendo una fuente de datos
#
# Los datos se obtienen del sito de datos abiertos de la ciudad de México, en particular de esta sección: https://datos.cdmx.gob.mx/dataset/afluencia-diaria-servicio-de-transportes-electricos

# %%
url="https://datos.cdmx.gob.mx/dataset/ee806dd2-c919-46f2-858f-6a55a05b8ee6/resource/36fb2606-9f11-4877-9149-d0b40b996551/download/afluencia_desglosada_trolebus_05_2023.csv"
df=pd.read_csv(url)
df
# Out:
#             fecha    mes  anio             linea  tipo_pago  afluencia
# 0      2022-01-01  Enero  2022           Línea 1     Boleto      16826
# 1      2022-01-01  Enero  2022           Línea 1    Prepago       5062
# 2      2022-01-01  Enero  2022           Línea 1  Gratuidad       9111
# 3      2022-01-01  Enero  2022  Línea 1 Nochebús     Boleto        131
# 4      2022-01-01  Enero  2022  Línea 1 Nochebús    Prepago         37
# ...           ...    ...   ...               ...        ...        ...
# 18013  2023-06-30  Junio  2023           Línea 9    Prepago       2479
# 18014  2023-06-30  Junio  2023           Línea 9  Gratuidad       2847
# 18015  2023-06-30  Junio  2023          Línea 10     Boleto          0
# 18016  2023-06-30  Junio  2023          Línea 10    Prepago      71103
# 18017  2023-06-30  Junio  2023          Línea 10  Gratuidad       6691
#
# [18018 rows x 6 columns]

# %%
df.describe()
# Out:
#                anio     afluencia
# count  18018.000000  18018.000000
# mean    2022.331502   6337.896659
# std        0.470766   9700.802535
# min     2022.000000      0.000000
# 25%     2022.000000    423.000000
# 50%     2022.000000   3196.000000
# 75%     2023.000000   7257.000000
# max     2023.000000  79500.000000

# %%
df['tipo_pago'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.plot(x="fecha",y="afluencia")
# Out:
# <Axes: xlabel='fecha'>

# %%
df[df['tipo_pago']=="Boleto"].plot(x="fecha",y="afluencia")
# Out:
# <Axes: xlabel='fecha'>

# %%
df[(df['tipo_pago']=="Boleto") & (df['linea']=="Línea 1")].plot(x="fecha",y="afluencia")
# Out:
# <Axes: xlabel='fecha'>

# %%
df2=pd.read_csv("https://datosabiertos.salud.gob.mx/gobmx/salud/datos_abiertos/datos_abiertos_covid19.zip")

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0                2023-08-01      0ed066       2      12          16     2
# 1                2023-08-01      28a1de       1       6           9     1
# 2                2023-08-01      061b65       1      12          13     2
# 3                2023-08-01      1b6d59       1      12           9     1
# 4                2023-08-01      11adf2       1      12          31     2
# ...                     ...         ...     ...     ...         ...   ...
# 1007464          2023-08-01     m181e49       2      12          15     1
# 1007465          2023-08-01     m07b940       2      12          15     1
# 1007466          2023-08-01     m12eff4       2       3          15     2
# 1007467          2023-08-01     m184665       2      12          15     2
# 1007468          2023-08-01     m0af074       2      12          15     2
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                 16           16             41              1  ...
# 1                  9            9             17              1  ...
# 2                  5           13             51              1  ...
# 3                  9            9             12              1  ...
# 4                 31           31             50              1  ...
# ...              ...          ...            ...            ...  ...
# 1007464           15           15            999              1  ...
# 1007465           15           15            999              1  ...
# 1007466           15           15            999              1  ...
# 1007467           15           15            999              1  ...
# 1007468           15           15            999              1  ...
#
#         OTRO_CASO TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# 0               2                2            97                      1
# 1               2                2            97                      1
# 2               1                1             2                      1
# 3               1                2            97                      1
# 4               2                2            97                      1
# ...           ...              ...           ...                    ...
# 1007464        99                1             4                      2
# 1007465        99                1             4                      2
# 1007466        99                2            97                      1
# 1007467        99                1             4                      2
# 1007468        99                1             4                      2
#
#          RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                         2                    7        99             México
# 1                         2                    7        99             México
# 2                         2                    7        99             México
# 3                         1                    3        99             México
# 4                         2                    7        99             México
# ...                     ...                  ...       ...                ...
# 1007464                  97                    6        99             México
# 1007465                  97                    6        99             México
# 1007466                   2                    7        99             México
# 1007467                  97                    6        99             México
# 1007468                  97                    6        99             México
#
#          PAIS_ORIGEN  UCI
# 0                 97   97
# 1                 97   97
# 2                 97   97
# 3                 97   97
# 4                 97   97
# ...              ...  ...
# 1007464           97   97
# 1007465           97   97
# 1007466           97   97
# 1007467           97   97
# 1007468           97   97
#
# [1007469 rows x 40 columns]>

# %%
df2[df2['SEXO']==1]
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 1                2023-08-01      28a1de       1       6           9     1
# 3                2023-08-01      1b6d59       1      12           9     1
# 5                2023-08-01      c4ec68       2      12           9     1
# 6                2023-08-01      b6d4ff       2      12           9     1
# 9                2023-08-01      db9c89       2      12           7     1
# ...                     ...         ...     ...     ...         ...   ...
# 1007457          2023-08-01     m04b593       2      12          15     1
# 1007460          2023-08-01     m08649b       2      12          15     1
# 1007462          2023-08-01     m020f17       2      12          15     1
# 1007464          2023-08-01     m181e49       2      12          15     1
# 1007465          2023-08-01     m07b940       2      12          15     1
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 1                  9            9             17              1  ...
# 3                  9            9             12              1  ...
# 5                  4            9              9              1  ...
# 6                  9            9              9              1  ...
# 9                  7            7            108              1  ...
# ...              ...          ...            ...            ...  ...
# 1007457           15           15            999              1  ...
# 1007460           15           15            999              1  ...
# 1007462           15           15            999              1  ...
# 1007464           15           15            999              1  ...
# 1007465           15           15            999              1  ...
#
#         OTRO_CASO TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# 1               2                2            97                      1
# 3               1                2            97                      1
# 5               2                2            97                      1
# 6               2                2            97                      1
# 9               2                2            97                      2
# ...           ...              ...           ...                    ...
# 1007457        99                1             4                      2
# 1007460        99                1             4                      2
# 1007462        99                1             4                      2
# 1007464        99                1             4                      2
# 1007465        99                1             4                      2
#
#          RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 1                         2                    7        99             México
# 3                         1                    3        99             México
# 5                         2                    7        99             México
# 6                         2                    7        99             México
# 9                        97                    6        99             México
# ...                     ...                  ...       ...                ...
# 1007457                  97                    6        99             México
# 1007460                  97                    6        99             México
# 1007462                  97                    6        99             México
# 1007464                  97                    6        99             México
# 1007465                  97                    6        99             México
#
#          PAIS_ORIGEN  UCI
# 1                 97   97
# 3                 97   97
# 5                 97   97
# 6                 97   97
# 9                 97   97
# ...              ...  ...
# 1007457           97   97
# 1007460           97   97
# 1007462           97   97
# 1007464           97   97
# 1007465           97   97
#
# [590770 rows x 40 columns]
